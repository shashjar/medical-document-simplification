# %% [markdown]
# ## Evaluate Model Performance

# %%
from typing import Dict, Tuple
import nltk

from tqdm import tqdm

import pandas as pd
from sklearn.model_selection import train_test_split

import numpy as np
from datasets import Dataset
import evaluate
import torch
import torch.nn as nn
from torch.optim import AdamW
from transformers import Trainer, T5Tokenizer, T5ForConditionalGeneration, TrainingArguments
from transformers import StoppingCriteria, StoppingCriteriaList
from transformers import BertModel, BertTokenizer, BertLMHeadModel, AutoModelForCausalLM, AutoTokenizer, BartModel, BartForConditionalGeneration
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

# %%
import eval_metrics as metrics

# %%
MIMIC_DATA_USAGE_ROWS = 5000
mimic_df = pd.read_csv("datasets/mimic-iv-ext-bhc/mimic-iv-bhc.csv", nrows=MIMIC_DATA_USAGE_ROWS)
mimic_df.rename(columns={'input': 'source'}, inplace=True)

mimic_sample = mimic_df.loc[0]['source']
mimic_target = mimic_df.loc[0]['target']

mimic_sample2 = mimic_df.loc[2]['source']
mimic_target2 = mimic_df.loc[2]['target']

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device {DEVICE}")
# Out:
# Using device cuda

# %% [markdown]
# ### T5

# %%
model_path = f"models/checkpoint-11500"

model = T5ForConditionalGeneration.from_pretrained(model_path)
tokenizer = T5Tokenizer.from_pretrained('t5-base')
model = model.to(DEVICE)
# Out:
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# C:\Users\andre\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\t5\tokenization_t5.py:240: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-base automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
MAX_LENGTH = 512

def summarize_text(text):
    inputs = tokenizer.encode(
        "summarize: " + text,
        return_tensors='pt',
        max_length=MAX_LENGTH,
        truncation=True
    )
    inputs = inputs.to(DEVICE)
 
    summary_ids = model.generate(
        inputs,
        encoder_repetition_penalty=1.8,
        no_repeat_ngram_size=3,
        max_length=50,
        num_beams=3,
        top_k=50,
    )
    
    summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
    
    if '.' in summary:
        summary = summary.split('.')[0] + '.'

    return summary

# %%
p1a = []
r1a = []
f1a = []
p2a = []
r2a = []
f2a = []
fka = []


for i in range(1000):
    sample = mimic_df.loc[i]['source']
    target = mimic_df.loc[i]['target']
    sum = summarize_text(sample)
    p1a.append(metrics.rouge_score(sample, sum, 1)['rouge1'][0])
    r1a.append(metrics.rouge_score(sample, sum, 1)['rouge1'][1])
    f1a.append(metrics.rouge_score(sample, sum, 1)['rouge1'][2])
    
    p2a.append(metrics.rouge_score(sample, sum, 2)['rouge2'][0])
    r2a.append(metrics.rouge_score(sample, sum, 2)['rouge2'][1])
    f2a.append(metrics.rouge_score(sample, sum, 2)['rouge2'][2])
    
    try:
        fka.append(metrics.flesch_kincaid(sum) - metrics.flesch_kincaid(target))
    except:
        pass
    
# rouge1 precision, recall, f1
print(np.mean(p1a))
print(np.mean(r1a))
print(np.mean(f1a))
# rouge2 precision, recall, f1
print(np.mean(p2a))
print(np.mean(r2a))
print(np.mean(f2a))
# delta flesch kincaid
print(np.mean(fka))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 13
#      11 sample = mimic_df.loc[i]['source']
#      12 target = mimic_df.loc[i]['target']
# ---> 13 sum = summarize_text(sample)
#      14 p1a.append(metrics.rouge_score(sample, sum, 1)['rouge1'][0])
#      15 r1a.append(metrics.rouge_score(sample, sum, 1)['rouge1'][1])
#
# Cell In[53], line 12, in summarize_text(text)
#       4 inputs = tokenizer.encode(
#       5     "summarize: " + text,
#       6     return_tensors='pt',
#       7     max_length=MAX_LENGTH,
#       8     truncation=True
#       9 )
#      10 inputs = inputs.to(DEVICE)
# ---> 12 summary_ids = model.generate(
#      13     inputs,
#      14     encoder_repetition_penalty=1.8,
#      15     no_repeat_ngram_size=3,
#      16     max_length=50,
#      17     num_beams=3,
#      18     top_k=50,
#      19 )
#      21 summary = tokenizer.decode(summary_ids[0], skip_special_tokens=True)
#      23 if '.' in summary:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\generation\utils.py:1752, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1745     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1746         input_ids=input_ids,
#    1747         expand_size=generation_config.num_beams,
#    1748         is_encoder_decoder=self.config.is_encoder_decoder,
#    1749         **model_kwargs,
#    1750     )
#    1751     # 13. run beam search
# -> 1752     return self.beam_search(
#    1753         input_ids,
#    1754         beam_scorer,
#    1755         logits_processor=logits_processor,
#    1756         stopping_criteria=stopping_criteria,
#    1757         pad_token_id=generation_config.pad_token_id,
#    1758         eos_token_id=generation_config.eos_token_id,
#    1759         output_scores=generation_config.output_scores,
#    1760         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1761         synced_gpus=synced_gpus,
#    1762         **model_kwargs,
#    1763     )
#    1765 elif generation_mode == GenerationMode.BEAM_SAMPLE:
#    1766     # 11. prepare logits warper
#    1767     logits_warper = self._get_logits_warper(generation_config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\generation\utils.py:3091, in GenerationMixin.beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    3087         break
#    3089 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
# -> 3091 outputs = self(
#    3092     **model_inputs,
#    3093     return_dict=True,
#    3094     output_attentions=output_attentions,
#    3095     output_hidden_states=output_hidden_states,
#    3096 )
#    3098 if synced_gpus and this_peer_finished:
#    3099     cur_len = cur_len + 1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\t5\modeling_t5.py:1746, in T5ForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1743         decoder_attention_mask = decoder_attention_mask.to(self.decoder.first_device)
#    1745 # Decode
# -> 1746 decoder_outputs = self.decoder(
#    1747     input_ids=decoder_input_ids,
#    1748     attention_mask=decoder_attention_mask,
#    1749     inputs_embeds=decoder_inputs_embeds,
#    1750     past_key_values=past_key_values,
#    1751     encoder_hidden_states=hidden_states,
#    1752     encoder_attention_mask=attention_mask,
#    1753     head_mask=decoder_head_mask,
#    1754     cross_attn_head_mask=cross_attn_head_mask,
#    1755     use_cache=use_cache,
#    1756     output_attentions=output_attentions,
#    1757     output_hidden_states=output_hidden_states,
#    1758     return_dict=return_dict,
#    1759 )
#    1761 sequence_output = decoder_outputs[0]
#    1763 # Set device for model parallelism
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\t5\modeling_t5.py:1113, in T5Stack.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1098     layer_outputs = self._gradient_checkpointing_func(
#    1099         layer_module.forward,
#    1100         hidden_states,
#    (...)
#    1110         output_attentions,
#    1111     )
#    1112 else:
# -> 1113     layer_outputs = layer_module(
#    1114         hidden_states,
#    1115         attention_mask=extended_attention_mask,
#    1116         position_bias=position_bias,
#    1117         encoder_hidden_states=encoder_hidden_states,
#    1118         encoder_attention_mask=encoder_extended_attention_mask,
#    1119         encoder_decoder_position_bias=encoder_decoder_position_bias,
#    1120         layer_head_mask=layer_head_mask,
#    1121         cross_attn_layer_head_mask=cross_attn_layer_head_mask,
#    1122         past_key_value=past_key_value,
#    1123         use_cache=use_cache,
#    1124         output_attentions=output_attentions,
#    1125     )
#    1127 # layer_outputs is a tuple with:
#    1128 # hidden-states, key-value-states, (self-attention position bias), (self-attention weights), (cross-attention position bias), (cross-attention weights)
#    1129 if use_cache is False:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\t5\modeling_t5.py:694, in T5Block.forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     691 else:
#     692     self_attn_past_key_value, cross_attn_past_key_value = None, None
# --> 694 self_attention_outputs = self.layer[0](
#     695     hidden_states,
#     696     attention_mask=attention_mask,
#     697     position_bias=position_bias,
#     698     layer_head_mask=layer_head_mask,
#     699     past_key_value=self_attn_past_key_value,
#     700     use_cache=use_cache,
#     701     output_attentions=output_attentions,
#     702 )
#     703 hidden_states, present_key_value_state = self_attention_outputs[:2]
#     704 attention_outputs = self_attention_outputs[2:]  # Keep self-attention outputs and relative position weights
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\t5\modeling_t5.py:600, in T5LayerSelfAttention.forward(self, hidden_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, output_attentions)
#     590 def forward(
#     591     self,
#     592     hidden_states,
#    (...)
#     598     output_attentions=False,
#     599 ):
# --> 600     normed_hidden_states = self.layer_norm(hidden_states)
#     601     attention_output = self.SelfAttention(
#     602         normed_hidden_states,
#     603         mask=attention_mask,
#    (...)
#     608         output_attentions=output_attentions,
#     609     )
#     610     hidden_states = hidden_states + self.dropout(attention_output[0])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\t5\modeling_t5.py:253, in T5LayerNorm.forward(self, hidden_states)
#     247 def forward(self, hidden_states):
#     248     # T5 uses a layer_norm which only scales and doesn't shift, which is also known as Root Mean
#     249     # Square Layer Normalization https://arxiv.org/abs/1910.07467 thus varience is calculated
#     250     # w/o mean and there is no bias. Additionally we want to make sure that the accumulation for
#     251     # half-precision inputs is done in fp32
# --> 253     variance = hidden_states.to(torch.float32).pow(2).mean(-1, keepdim=True)
#     254     hidden_states = hidden_states * torch.rsqrt(variance + self.variance_epsilon)
#     256     # convert into half-precision if necessary
#
# KeyboardInterrupt:

# %% [markdown]
# ### BART

# %%
model_path = f"models/checkpoint-1000"
model = AutoModelForSeq2SeqLM.from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = model.to(DEVICE)

# %%
MAX_LENGTH = 1024

def summarize_text(text):
    # Preprocess the text
    inputs = tokenizer.encode(
        "summarize: " + text,
        return_tensors='pt',
        max_length=MAX_LENGTH,
        truncation=True
    )
    inputs = inputs.to(DEVICE)
 
    # Generate the summary
    summary_ids = model.generate(
        inputs,
        # encoder_repetition_penalty=0.9,
        no_repeat_ngram_size=4,
        max_length=750,
        num_beams=5,
        temperature=1,
    )
 
    # Decode and return the summary
    return tokenizer.decode(summary_ids[0], skip_special_tokens=True)

# %%
p1a = []
r1a = []
f1a = []
p2a = []
r2a = []
f2a = []
fka = []


for i in range(1000):
    sample = mimic_df.loc[i]['source']
    target = mimic_df.loc[i]['target']
    sum = summarize_text(sample)
    p1a.append(metrics.rouge_score(sample, sum, 1)['rouge1'][0])
    r1a.append(metrics.rouge_score(sample, sum, 1)['rouge1'][1])
    f1a.append(metrics.rouge_score(sample, sum, 1)['rouge1'][2])
    
    p2a.append(metrics.rouge_score(sample, sum, 2)['rouge2'][0])
    r2a.append(metrics.rouge_score(sample, sum, 2)['rouge2'][1])
    f2a.append(metrics.rouge_score(sample, sum, 2)['rouge2'][2])
    
    try:
        fka.append(metrics.flesch_kincaid(sum) - metrics.flesch_kincaid(target))
    except:
        pass
    
# rouge1 precision, recall, f1
print(np.mean(p1a))
print(np.mean(r1a))
print(np.mean(f1a))
# rouge2 precision, recall, f1
print(np.mean(p2a))
print(np.mean(r2a))
print(np.mean(f2a))
# delta flesch kincaid
print(np.mean(fka))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 13
#      11 sample = mimic_df.loc[i]['source']
#      12 target = mimic_df.loc[i]['target']
# ---> 13 sum = summarize_text(sample)
#      14 p1a.append(metrics.rouge_score(sample, sum, 1)['rouge1'][0])
#      15 r1a.append(metrics.rouge_score(sample, sum, 1)['rouge1'][1])
#
# Cell In[37], line 14, in summarize_text(text)
#      11 inputs = inputs.to(DEVICE)
#      13 # Generate the summary
# ---> 14 summary_ids = model.generate(
#      15     inputs,
#      16     # encoder_repetition_penalty=0.9,
#      17     no_repeat_ngram_size=4,
#      18     max_length=750,
#      19     num_beams=5,
#      20     temperature=1,
#      21 )
#      23 # Decode and return the summary
#      24 return tokenizer.decode(summary_ids[0], skip_special_tokens=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\generation\utils.py:1752, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1745     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1746         input_ids=input_ids,
#    1747         expand_size=generation_config.num_beams,
#    1748         is_encoder_decoder=self.config.is_encoder_decoder,
#    1749         **model_kwargs,
#    1750     )
#    1751     # 13. run beam search
# -> 1752     return self.beam_search(
#    1753         input_ids,
#    1754         beam_scorer,
#    1755         logits_processor=logits_processor,
#    1756         stopping_criteria=stopping_criteria,
#    1757         pad_token_id=generation_config.pad_token_id,
#    1758         eos_token_id=generation_config.eos_token_id,
#    1759         output_scores=generation_config.output_scores,
#    1760         return_dict_in_generate=generation_config.return_dict_in_generate,
#    1761         synced_gpus=synced_gpus,
#    1762         **model_kwargs,
#    1763     )
#    1765 elif generation_mode == GenerationMode.BEAM_SAMPLE:
#    1766     # 11. prepare logits warper
#    1767     logits_warper = self._get_logits_warper(generation_config)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\generation\utils.py:3091, in GenerationMixin.beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, **model_kwargs)
#    3087         break
#    3089 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
# -> 3091 outputs = self(
#    3092     **model_inputs,
#    3093     return_dict=True,
#    3094     output_attentions=output_attentions,
#    3095     output_hidden_states=output_hidden_states,
#    3096 )
#    3098 if synced_gpus and this_peer_finished:
#    3099     cur_len = cur_len + 1
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bart\modeling_bart.py:1577, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1572     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1573         decoder_input_ids = shift_tokens_right(
#    1574             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1575         )
# -> 1577 outputs = self.model(
#    1578     input_ids,
#    1579     attention_mask=attention_mask,
#    1580     decoder_input_ids=decoder_input_ids,
#    1581     encoder_outputs=encoder_outputs,
#    1582     decoder_attention_mask=decoder_attention_mask,
#    1583     head_mask=head_mask,
#    1584     decoder_head_mask=decoder_head_mask,
#    1585     cross_attn_head_mask=cross_attn_head_mask,
#    1586     past_key_values=past_key_values,
#    1587     inputs_embeds=inputs_embeds,
#    1588     decoder_inputs_embeds=decoder_inputs_embeds,
#    1589     use_cache=use_cache,
#    1590     output_attentions=output_attentions,
#    1591     output_hidden_states=output_hidden_states,
#    1592     return_dict=return_dict,
#    1593 )
#    1595 lm_logits = self.lm_head(outputs[0])
#    1596 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bart\modeling_bart.py:1463, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1456     encoder_outputs = BaseModelOutput(
#    1457         last_hidden_state=encoder_outputs[0],
#    1458         hidden_states=encoder_outputs[1] if len(encoder_outputs) > 1 else None,
#    1459         attentions=encoder_outputs[2] if len(encoder_outputs) > 2 else None,
#    1460     )
#    1462 # decoder outputs consists of (dec_features, past_key_value, dec_hidden, dec_attn)
# -> 1463 decoder_outputs = self.decoder(
#    1464     input_ids=decoder_input_ids,
#    1465     attention_mask=decoder_attention_mask,
#    1466     encoder_hidden_states=encoder_outputs[0],
#    1467     encoder_attention_mask=attention_mask,
#    1468     head_mask=decoder_head_mask,
#    1469     cross_attn_head_mask=cross_attn_head_mask,
#    1470     past_key_values=past_key_values,
#    1471     inputs_embeds=decoder_inputs_embeds,
#    1472     use_cache=use_cache,
#    1473     output_attentions=output_attentions,
#    1474     output_hidden_states=output_hidden_states,
#    1475     return_dict=return_dict,
#    1476 )
#    1478 if not return_dict:
#    1479     return decoder_outputs + encoder_outputs
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bart\modeling_bart.py:1316, in BartDecoder.forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, head_mask, cross_attn_head_mask, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1303     layer_outputs = self._gradient_checkpointing_func(
#    1304         decoder_layer.__call__,
#    1305         hidden_states,
#    (...)
#    1313         use_cache,
#    1314     )
#    1315 else:
# -> 1316     layer_outputs = decoder_layer(
#    1317         hidden_states,
#    1318         attention_mask=attention_mask,
#    1319         encoder_hidden_states=encoder_hidden_states,
#    1320         encoder_attention_mask=encoder_attention_mask,
#    1321         layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#    1322         cross_attn_layer_head_mask=(
#    1323             cross_attn_head_mask[idx] if cross_attn_head_mask is not None else None
#    1324         ),
#    1325         past_key_value=past_key_value,
#    1326         output_attentions=output_attentions,
#    1327         use_cache=use_cache,
#    1328     )
#    1329 hidden_states = layer_outputs[0]
#    1331 if use_cache:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bart\modeling_bart.py:655, in BartDecoderLayer.forward(self, hidden_states, attention_mask, encoder_hidden_states, encoder_attention_mask, layer_head_mask, cross_attn_layer_head_mask, past_key_value, output_attentions, use_cache)
#     653 # cross_attn cached key/values tuple is at positions 3,4 of present_key_value tuple
#     654 cross_attn_past_key_value = past_key_value[-2:] if past_key_value is not None else None
# --> 655 hidden_states, cross_attn_weights, cross_attn_present_key_value = self.encoder_attn(
#     656     hidden_states=hidden_states,
#     657     key_value_states=encoder_hidden_states,
#     658     attention_mask=encoder_attention_mask,
#     659     layer_head_mask=cross_attn_layer_head_mask,
#     660     past_key_value=cross_attn_past_key_value,
#     661     output_attentions=output_attentions,
#     662 )
#     663 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     664 hidden_states = residual + hidden_states
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\bart\modeling_bart.py:187, in BartAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     184 bsz, tgt_len, _ = hidden_states.size()
#     186 # get query proj
# --> 187 query_states = self.q_proj(hidden_states) * self.scaling
#     188 # get key, value proj
#     189 # `past_key_value[0].shape[2] == key_value_states.shape[1]`
#     190 # is checking that the `sequence_length` of the `past_key_value` is the same as
#     191 # the provided `key_value_states` to support prefix tuning
#     192 if (
#     193     is_cross_attention
#     194     and past_key_value is not None
#     195     and past_key_value[0].shape[2] == key_value_states.shape[1]
#     196 ):
#     197     # reuse k,v, cross_attentions
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\torch\nn\modules\linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:

# %%
print(fka)
# Out:
# [0.17743931475028774, -1.5564432539317536]
